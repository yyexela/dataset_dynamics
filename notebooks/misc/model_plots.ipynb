# %% [markdown]
# ## Description
#
# Collection of data for transition frames and model parameters. Plotted using plotly.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
from pathlib import Path
import pandas as pd
import numpy as np

# Update path to include mypkg
sys.path.insert(0, str(Path(os.path.abspath('')).parent.parent.absolute()))
print(sys.path)

from src import helpers, plot_data, global_config, datasets
config = global_config.config

# save figures
save = False
# Out:
# ['/Users/alexey/Git/dataset_dynamics', '/Users/alexey/.pyenv/versions/3.10.18/lib/python310.zip', '/Users/alexey/.pyenv/versions/3.10.18/lib/python3.10', '/Users/alexey/.pyenv/versions/3.10.18/lib/python3.10/lib-dynload', '', '/Users/alexey/.virtualenvs/latent/lib/python3.10/site-packages', '__editable__.latent_spaces-0.1.finder.__path_hook__']

# %%
# FMNIST

fmnist_data_3 = pd.DataFrame(data = {
    "transition frame"  : [2, 4, 10, 17, 26, 36, 48, 65, 81, 101, 122, 145, 170, 197, 226, 256, 289, 324, 361, 402],
    #"hole" : [0, 0, 0, 0, 0],
    "layers" : [[784,1,784],[784,4,784],[784,9,784],[784,16,784],[784,25,784],[784,36,784],[784,49,784],[784,64,784],[784,81,784],[784,100,784],[784,121,784],[784,144,784],[784,169,784],[784,196,784],[784,225,784],[784,256,784],[784,289,784],[784,324,784],[784,361,784],[784,400,784]],
    "loss" : [0.0870203407386602, 0.03674670542448254, 0.025518305883821795, 0.02103960899225736, 0.01736452020073341, 0.014543906185712855, 0.012144576584509873, 0.010411130611674261, 0.008940654001751189, 0.007713364500362994, 0.0066548616199170125, 0.0057314546084252455, 0.004909758432373657, 0.0042140424583044095, 0.003572400714570688, 0.003013601641060185, 0.0025159120559692383, 0.0020768476010821126, 0.0016906089820283448, 0.0013498111797686097]
})
model_params = [helpers.layer_counter(layer) for layer in list(fmnist_data_3["layers"])]
fmnist_data_3.insert(2, "model size", model_params)
bottleneck_size = [layer[1] for layer in list(fmnist_data_3["layers"])]
fmnist_data_3.insert(3, "bottleneck size", bottleneck_size)

# NOTES: FMNIST_11 frame 144 has a singularity looking thing

# 28-55
fmnist_data_5 = pd.DataFrame(data = {
    "transition frame"  : [1, 78, 127, 150, 165, 170, 145, 163, 150, 176, 180, 188, 200, 218, 268, 294, 310, 325, 328, 345, 348, 348, 358, 365, 368, 394, 419, 414],
    "layers" : [[784, 392, 1, 392, 784],
        [784, 394, 4, 394, 784],
        [784, 396, 9, 396, 784],
        [784, 400, 16, 400, 784],
        [784, 404, 25, 404, 784],
        [784, 410, 36, 410, 784],
        [784, 416, 49, 416, 784],
        [784, 424, 64, 424, 784],
        [784, 432, 81, 432, 784],
        [784, 442, 100, 442, 784],
        [784, 452, 121, 452, 784],
        [784, 464, 144, 464, 784],
        [784, 476, 169, 476, 784],
        [784, 490, 196, 490, 784],
        [784, 504, 225, 504, 784],
        [784, 520, 256, 520, 784],
        [784, 536, 289, 536, 784],
        [784, 554, 324, 554, 784],
        [784, 572, 361, 572, 784],
        [784, 592, 400, 592, 784],
        [784, 612, 441, 612, 784],
        [784, 634, 484, 634, 784],
        [784, 656, 529, 656, 784],
        [784, 680, 576, 680, 784],
        [784, 704, 625, 704, 784],
        [784, 730, 676, 730, 784],
        [784, 756, 729, 756, 784],
        [784, 784, 784, 784, 784]],
    "loss" : [0.08704155115252835, 0.021429435839339837, 0.014915549275228533, 0.01250740710519633, 0.010914895573031094, 0.010010797088429078, 0.009214418529832766, 0.008195783461491435, 0.007205525476296069, 0.006489712855447147, 0.005877485561926486, 0.005299782988189136, 0.004775048588734057, 0.004221698095611596, 0.0038863441441208124, 0.003258532512996156, 0.0029091835337675225, 0.0026282712825084643, 0.0026912135782383257, 0.0021897917021444792, 0.0020512597974768633, 0.001915312127478547, 0.0018788370228830283, 0.0016656245195733035, 0.001554371009707072, 0.0014562679580965284, 0.001459190128686822, 0.0013053193570004176]
})
fmnist_data_5 = fmnist_data_5.set_index(pd.RangeIndex(28, 28+fmnist_data_5.shape[0]))
model_params = [helpers.layer_counter(layer) for layer in list(fmnist_data_5["layers"])]
fmnist_data_5.insert(2, "model size", model_params)
bottleneck_size = [layer[2] for layer in list(fmnist_data_5["layers"])]
fmnist_data_5.insert(3, "bottleneck size", bottleneck_size)

# NOTES: 

# MNIST

mnist_data_3 = pd.DataFrame(data = {
    "transition frame"  : [2, 5, 10, 17, 26, 37, 50, 65, 82, 101, 121, 144, 170, 197, 225, 256],
    "layers" : [[784,1,784],[784,4,784],[784,9,784],[784,16,784],[784,25,784],[784,36,784],[784,49,784],[784,64,784],[784,81,784],[784,100,784],[784,121,784],[784,144,784],[784,169,784],[784,196,784],[784,225,784],[784,256,784]],
    "loss" : [0.06083928736842285, 0.04825888668834153, 0.037948426743180066, 0.02742026774686272, 0.020736622040049505, 0.01575230327198061, 0.01203041553686736, 0.009329057251245288, 0.007306125796384225, 0.005773911513072454, 0.0046280126513566005, 0.003713465204967533, 0.002975192564239694, 0.0023779498957792076, 0.0018698958723442787, 0.0014358873072601224]
})
model_params = [helpers.layer_counter(layer) for layer in list(mnist_data_3["layers"])]
mnist_data_3.insert(2, "model size", model_params)
bottleneck_size = [layer[1] for layer in list(mnist_data_3["layers"])]
mnist_data_3.insert(3, "bottleneck size", bottleneck_size)

# NOTES: MNIST_11 frame 144 has singularity, MNIST_12 frame 169 has singularity, MNIST_13 frame 196 has singularity

mnist_data_5 = pd.DataFrame(data = {
    "transition frame"  : [1, 91, 115, 129, 133, 121, 108, 99, 98, 103, 118, 135, 152, 176, 207, 236, 259, 292],
    "layers" : [[784, 392, 1, 392, 784],
        [784, 394, 4, 394, 784],
        [784, 396, 9, 396, 784],
        [784, 400, 16, 400, 784],
        [784, 404, 25, 404, 784],
        [784, 410, 36, 410, 784],
        [784, 416, 49, 416, 784],
        [784, 424, 64, 424, 784],
        [784, 432, 81, 432, 784],
        [784, 442, 100, 442, 784],
        [784, 452, 121, 452, 784],
        [784, 464, 144, 464, 784],
        [784, 476, 169, 476, 784],
        [784, 490, 196, 490, 784],
        [784, 504, 225, 504, 784],
        [784, 520, 256, 520, 784],
        [784, 536, 289, 536, 784],
        [784, 554, 324, 554, 784]],
    "loss" : [0.06729540216215586, 0.028462397629174137, 0.02038766636307967, 0.01525088636425592, 0.012462088996070927, 0.011656198855805195, 0.010007246855204389, 0.008174621586893069, 0.007230497786175396, 0.005640231293894477, 0.004943684067071999, 0.004062371569196299, 0.0032553738219884493, 0.0026504153433113786, 0.0022056634593123603, 0.0019673782566530726, 0.0014157753015505308, 0.0012445521947406864]
})
mnist_data_5 = mnist_data_5.set_index(pd.RangeIndex(28, 28+mnist_data_5.shape[0]))
model_params = [helpers.layer_counter(layer) for layer in list(mnist_data_5["layers"])]
mnist_data_5.insert(2, "model size", model_params)
bottleneck_size = [layer[2] for layer in list(mnist_data_5["layers"])]
mnist_data_5.insert(3, "bottleneck size", bottleneck_size)

# NOTES: 

fmnist_data_4 = pd.DataFrame(data = {
    "transition frame"  : [1,4,7,10,20,33,45,61,74,96,113,137,156,189,211,236,270,305,325,367],
    "layers" : [[784,1,1,784],[784,4,4,784],[784,9,9,784],[784,16,16,784],[784, 25, 25, 784],[784, 36, 36, 784],[784, 49, 49, 784],[784, 64, 64, 784],[784, 81, 81, 784],[784, 100, 100, 784],[784,121,121,784],[784, 144, 144, 784],[784, 169, 169, 784],[784, 196, 196, 784],[784, 225, 225, 784],[784, 256, 256, 784],[784,289,289,784],[784, 324, 324, 784],[784, 361, 361, 784],[784, 400, 400, 784]],
    "loss" : [0.08702036788908102, 0.04105951876963599, 0.03038797167650724, 0.025521322990120467, 0.018673158298104495,0.015191121579353081,0.01273410311126608,0.010918046979202052, 0.00969092598405935,0.008037589711405464,0.007106745292006408,0.006081973155171184,0.00542139455328806,0.004493405513654826,0.003991130108045319,0.003498068990943543,0.0029550549905684033,0.0024769992480780613,0.0021929463324279097,0.0018697600649922328]
})

fmnist_data_4 = fmnist_data_4.set_index(pd.RangeIndex(28*3, 28*3+fmnist_data_4.shape[0]))
model_params = [helpers.layer_counter(layer) for layer in list(fmnist_data_4["layers"])]
fmnist_data_4.insert(2, "model size", model_params)
bottleneck_size = [layer[1] for layer in list(fmnist_data_4["layers"])]
fmnist_data_4.insert(3, "bottleneck size", bottleneck_size)

# NOTES:

mnist_data_4 = pd.DataFrame(data = {
    "transition frame"  : [1,4,7,15,21,35,48,58,75,94,115, 131,158,184,203,236,264,298],
    "layers" : [[784,1,1,784],[784,4,4,784],[784,9,9,784],[784,16,16,784],[784, 25, 25, 784],[784, 36, 36, 784],[784, 49, 49, 784],[784, 64, 64, 784],[784, 81, 81, 784],[784, 100, 100, 784],[784,121,121,784],[784, 144, 144, 784],[784, 169, 169, 784],[784, 196, 196, 784],[784, 225, 225, 784],[784, 256, 256, 784],[784,289,289,784],[784, 324, 324, 784],],
    "loss" : [0.0672761749918178,0.05215220500604581,0.042015588510844665,0.029396405538259927,0.024016326830043632,0.01647614250433142,0.012524824968333972,0.010452422250251649,0.00802445327231692,0.006297683390646668,0.004981749422721944,0.004253713769238379,0.0033539842056520917,0.0027051279755403936,0.0023066886361309533,0.001793091712219609,0.0014268804235005024,0.0010758016822796505]
})

mnist_data_4 = mnist_data_4.set_index(pd.RangeIndex(28*3, 28*3+mnist_data_4.shape[0]))
model_params = [helpers.layer_counter(layer) for layer in list(mnist_data_4["layers"])]
mnist_data_4.insert(2, "model size", model_params)
bottleneck_size = [layer[1] for layer in list(mnist_data_4["layers"])]
mnist_data_4.insert(3, "bottleneck size", bottleneck_size)

# NOTES: model 94 frame 114 has singularity

fmnist_data_6 = pd.DataFrame(data = {
    "transition frame"  : [1, 37, 97, 149, 140, 150, 169, 174, 180, 202, 203, 200, 208, 220, 226, 235, 250, 259, 275, 270, 277, 277, 283, 310, 320, 330, 330, 340],
    "layers" : [[784, 392, 1, 1, 392, 784],[784, 394, 4, 4, 394, 784],[784, 396, 9, 9, 396, 784],[784, 400, 16, 16, 400, 784],[784, 404, 25, 25, 404, 784],[784, 410, 36, 36, 410, 784],[784, 416, 49, 49, 416, 784],[784, 424, 64, 64, 424, 784],[784, 432, 81, 81, 432, 784],[784, 442, 100, 100, 442, 784],[784, 452, 121, 121, 452, 784],[784, 464, 144, 144, 464, 784],[784, 476, 169, 169, 476, 784],[784, 490, 196, 196, 490, 784],[784, 504, 225, 225, 504, 784],[784, 520, 256, 256, 520, 784],[784, 536, 289, 289, 536, 784],[784, 554, 324, 324, 554, 784],[784, 572, 361, 361, 572, 784],[784, 592, 400, 400, 592, 784],[784, 612, 441, 441, 612, 784],[784, 634, 484, 484, 634, 784],[784, 656, 529, 529, 656, 784],[784, 680, 576, 576, 680, 784],[784, 704, 625, 625, 704, 784],[784, 730, 676, 676, 730, 784],[784, 756, 729, 729, 756, 784],[784, 784, 784, 784, 784, 784]],
    "loss" : [0.08704072451692517,0.02681315317749977,0.016653581159347196,0.012850214253669069,0.011374072550590766,0.009993913962300552,0.00903693029372874,0.008240177974862567,0.007673528913597939,0.006796490795657796,0.006161783324649273,0.005911419168114662,0.005287633435327118,0.00506828790846265,0.004655223316118374,0.004420260212115817,0.004033255745988276,0.0038441542291350788,0.0035599637460910667,0.003437511650529706,0.00345328002299924,0.003133047975883898,0.00288537435107312,0.002827825660075424,0.002669112745009489,0.002533235918667357,0.0024418396109683535,0.002369262124174985]
})

fmnist_data_6 = fmnist_data_6.set_index(pd.RangeIndex(28*2, 28*2+fmnist_data_6.shape[0]))
model_params = [helpers.layer_counter(layer) for layer in list(fmnist_data_6["layers"])]
fmnist_data_6.insert(2, "model size", model_params)
bottleneck_size = [layer[2] for layer in list(fmnist_data_6["layers"])]
fmnist_data_6.insert(3, "bottleneck size", bottleneck_size)

# NOTES:

mnist_data_6 = pd.DataFrame(data = {
    "transition frame"  : [1, 90, 114, 132, 133, 133, 124, 117, 112, 115, 125, 130, 140, 153, 170, 180, 170, 190, 190, 190, 200, 210, 213, 223, 230, 250, 250, 250],
    "layers" : [[784, 392, 1, 1, 392, 784],[784, 394, 4, 4, 394, 784],[784, 396, 9, 9, 396, 784],[784, 400, 16, 16, 400, 784],[784, 404, 25, 25, 404, 784],[784, 410, 36, 36, 410, 784],[784, 416, 49, 49, 416, 784],[784, 424, 64, 64, 424, 784],[784, 432, 81, 81, 432, 784],[784, 442, 100, 100, 442, 784],[784, 452, 121, 121, 452, 784],[784, 464, 144, 144, 464, 784],[784, 476, 169, 169, 476, 784],[784, 490, 196, 196, 490, 784],[784, 504, 225, 225, 504, 784],[784, 520, 256, 256, 520, 784],[784, 536, 289, 289, 536, 784],[784, 554, 324, 324, 554, 784],[784, 572, 361, 361, 572, 784],[784, 592, 400, 400, 592, 784],[784, 612, 441, 441, 612, 784],[784, 634, 484, 484, 634, 784],[784, 656, 529, 529, 656, 784],[784, 680, 576, 576, 680, 784],[784, 704, 625, 625, 704, 784],[784, 730, 676, 676, 730, 784],[784, 756, 729, 729, 756, 784],[784, 784, 784, 784, 784, 784]],
    "loss" : [0.06729653730230817,0.032931859778650735,0.025753881908574347,0.016661971144504465,0.013539930489861358,0.010602687027747347,0.009291176068580757,0.008285959030233197,0.007101036758177867,0.006086291042866849,0.005010923062908953,0.004314814110176038,0.003979546254721738,0.0035514001639843995,0.003106378026748613,0.0028489885567608525,0.0026218800063608056,0.002270359672227148,0.002241528186536694,0.0020038352635989,0.001800197038515392,0.0017088133056442868,0.001590596772414648,0.0015065335684408575,0.0014618221883488409,0.0013166943454515126,0.0012428792710494944,0.0011861858775018383]
})

mnist_data_6 = mnist_data_6.set_index(pd.RangeIndex(28*2, 28*2+mnist_data_6.shape[0]))
model_params = [helpers.layer_counter(layer) for layer in list(mnist_data_6["layers"])]
mnist_data_6.insert(2, "model size", model_params)
bottleneck_size = [layer[2] for layer in list(mnist_data_6["layers"])]
mnist_data_6.insert(3, "bottleneck size", bottleneck_size)

# NOTES:

#print(fmnist_data_3)

# %%
xs = [list(mnist_data_3.index), list(fmnist_data_3.index)]
ys = [mnist_data_3['transition frame'].to_numpy(), fmnist_data_3['transition frame'].to_numpy()]
labels = ["MNIST_3", "FMNIST_3"]
title = "Transition frames for 3 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Number"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "3_layers_model_num"))

# %%
xs = [list(mnist_data_4.index), list(fmnist_data_4.index)]
ys = [mnist_data_4['transition frame'].to_numpy(), fmnist_data_4['transition frame'].to_numpy()]
labels = ["MNIST_4", "FMNIST_4"]
title = "Transition frames for 4 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Number"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "4_layers_model_num"))

# %%
xs = [list(mnist_data_5.index), list(fmnist_data_5.index)]
ys = [mnist_data_5['transition frame'].to_numpy(), fmnist_data_5['transition frame'].to_numpy()]
labels = ["MNIST_5", "FMNIST_5"]
title = "Transition frames for 5 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Number"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "5_layers_model_num"))

# %%
xs = [list(mnist_data_6.index), list(fmnist_data_6.index)]
ys = [mnist_data_6['transition frame'].to_numpy(), fmnist_data_6['transition frame'].to_numpy()]
labels = ["MNIST_6", "FMNIST_6"]
title = "Transition frames for 6 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Number"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "6_layers_model_num"))

# %%
xs = [mnist_data_3['model size'].to_numpy(), fmnist_data_3['model size'].to_numpy()]
ys = [mnist_data_3['transition frame'].to_numpy(), fmnist_data_3['transition frame'].to_numpy()]
labels = ["MNIST_3", "FMNIST_3"]
title = "Transition frames for 3 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Parameters"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "3_layers_model_param"))

# %%
xs = [mnist_data_4['model size'].to_numpy(), fmnist_data_4['model size'].to_numpy()]
ys = [mnist_data_4['transition frame'].to_numpy(), fmnist_data_4['transition frame'].to_numpy()]
labels = ["MNIST_4", "FMNIST_4"]
title = "Transition frames for 4 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Parameters"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "4_layers_model_param"))

# %%
xs = [mnist_data_5['model size'].to_numpy(), fmnist_data_5['model size'].to_numpy()]
ys = [mnist_data_5['transition frame'].to_numpy(), fmnist_data_5['transition frame'].to_numpy()]
labels = ["MNIST_5", "FMNIST_5"]
title = "Transition frames for 5 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Parameters"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "5_layers_model_param"))

# %%
xs = [mnist_data_6['model size'].to_numpy(), fmnist_data_6['model size'].to_numpy()]
ys = [mnist_data_6['transition frame'].to_numpy(), fmnist_data_6['transition frame'].to_numpy()]
labels = ["MNIST_6", "FMNIST_6"]
title = "Transition frames for 6 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Parameters"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "6_layers_model_param"))

# %%
xs = [mnist_data_3['loss'].to_numpy(), fmnist_data_3['loss'].to_numpy()]
ys = [mnist_data_3['transition frame'].to_numpy(), fmnist_data_3['transition frame'].to_numpy()]
labels = ["MNIST_3", "FMNIST_3"]
title = "Transition frames for 3 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Loss"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "3_layers_model_loss"))

# %%
xs = [mnist_data_4['loss'].to_numpy(), fmnist_data_4['loss'].to_numpy()]
ys = [mnist_data_4['transition frame'].to_numpy(), fmnist_data_4['transition frame'].to_numpy()]
labels = ["MNIST_4", "FMNIST_4"]
title = "Transition frames for 4 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Loss"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "4_layers_model_loss"))

# %%
xs = [mnist_data_5['loss'].to_numpy(), fmnist_data_5['loss'].to_numpy()]
ys = [mnist_data_5['transition frame'].to_numpy(), fmnist_data_5['transition frame'].to_numpy()]
labels = ["MNIST_5", "FMNIST_5"]
title = "Transition frames for 5 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Loss"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "5_layers_model_loss"))

# %%
xs = [mnist_data_6['loss'].to_numpy(), fmnist_data_6['loss'].to_numpy()]
ys = [mnist_data_6['transition frame'].to_numpy(), fmnist_data_6['transition frame'].to_numpy()]
labels = ["MNIST_6", "FMNIST_6"]
title = "Transition frames for 6 layer AEs on FMNIST and MNIST"
xaxis_title = "Model Loss"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "6_layers_model_loss"))

# %%
xs = [mnist_data_3['bottleneck size'].to_numpy(), fmnist_data_3['bottleneck size'].to_numpy()]
ys = [mnist_data_3['transition frame'].to_numpy(), fmnist_data_3['transition frame'].to_numpy()]
labels = ["MNIST_3", "FMNIST_3"]
title = "Transition frames for 3 layer AEs on FMNIST and MNIST Over Bottleneck Size"
xaxis_title = "Bottleneck Size"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "3_layers_bottleneck_size"))

# %%
xs = [mnist_data_4['bottleneck size'].to_numpy(), fmnist_data_4['bottleneck size'].to_numpy()]
ys = [mnist_data_4['transition frame'].to_numpy(), fmnist_data_4['transition frame'].to_numpy()]
labels = ["MNIST_4", "FMNIST_4"]
title = "Transition frames for 4 layer AEs on FMNIST and MNIST Over Bottleneck Size"
xaxis_title = "Bottleneck Size"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "4_layers_bottleneck_size"))

# %%
xs = [mnist_data_5['bottleneck size'].to_numpy(), fmnist_data_5['bottleneck size'].to_numpy()]
ys = [mnist_data_5['transition frame'].to_numpy(), fmnist_data_5['transition frame'].to_numpy()]
labels = ["MNIST_5", "FMNIST_5"]
title = "Transition frames for 5 layer AEs on FMNIST and MNIST Over Bottleneck Size"
xaxis_title = "Bottleneck Size"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "5_layers_bottleneck_size"))

# %%
xs = [mnist_data_6['bottleneck size'].to_numpy(), fmnist_data_6['bottleneck size'].to_numpy()]
ys = [mnist_data_6['transition frame'].to_numpy(), fmnist_data_6['transition frame'].to_numpy()]
labels = ["MNIST_6", "FMNIST_6"]
title = "Transition frames for 6 layer AEs on FMNIST and MNIST Over Bottleneck Size"
xaxis_title = "Bottleneck Size"
yaxis_title = "Transition Frame"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "5_layers_bottleneck_size"))

# %%
xs = [mnist_data_3['model size'].to_numpy(), fmnist_data_3['model size'].to_numpy()]
ys = [mnist_data_3['loss'].to_numpy(), fmnist_data_3['loss'].to_numpy()]
labels = ["MNIST_3", "FMNIST_3"]
title = "Transition frames for 3 layer AEs on FMNIST and MNIST Over Bottleneck Size"
xaxis_title = "Model Parameters"
yaxis_title = "Final Loss"

plot_data.plot_line(x=xs, y=ys, label=labels, title=title, xaxis_title=xaxis_title, yaxis_title=yaxis_title, save=save, fname=os.path.join(config.jpg_dir, "3_layers_loss_to_model_size"))
